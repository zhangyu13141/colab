# %%
# !git clone https://github.com/WangWenhao0716/Adapted-Center-and-Scale-Prediction.git
# Out:
# Cloning into 'Adapted-Center-and-Scale-Prediction'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 410 (delta 31), reused 0 (delta 0), pack-reused 351
# Receiving objects: 100% (410/410), 1.02 MiB | 2.44 MiB/s, done.
# Resolving deltas: 100% (158/158), done.

# %%
cd /content/Adapted-Center-and-Scale-Prediction/models
# Out:
# /content/Adapted-Center-and-Scale-Prediction/models

# %%
# !pip install gdown

# %%
cd ..
# Out:
# /content/Adapted-Center-and-Scale-Prediction

# %%
cd util
# Out:
# /content/Adapted-Center-and-Scale-Prediction/util

# %%
# !make all
# Out:
# python setup.py build_ext --inplace
# running build_ext
# cythoning nms/cpu_nms.pyx to nms/cpu_nms.c
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/Adapted-Center-and-Scale-Prediction/util/nms/cpu_nms.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'nms.cpu_nms' extension
# creating build
# creating build/temp.linux-x86_64-3.6
# creating build/temp.linux-x86_64-3.6/nms
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.6/dist-packages/numpy/core/include -I/usr/include/python3.6m -c nms/cpu_nms.c -o build/temp.linux-x86_64-3.6/nms/cpu_nms.o -Wno-cpp -Wno-unused-function
# ...

# %%
cd ..
# Out:
# /content/Adapted-Center-and-Scale-Prediction

# %%
cp -r '/content/drive/My Drive/CSP/CSP/data/images/val' /content/Adapted-Center-and-Scale-Prediction/data/citypersons/images

# %%
mv '/content/drive/My Drive/Colab Notebooks/ResNet101v2+SN(8,32)(1).pth' /content/Adapted-Center-and-Scale-Prediction/models

# %%
mv '/content/drive/My Drive/Colab Notebooks/ACSP(Smooth L1).pth.tea' /content/Adapted-Center-and-Scale-Prediction/models

# %%
mv '/content/drive/My Drive/Colab Notebooks/ACSP(Vanilla L1).pth.tea' /content/Adapted-Center-and-Scale-Prediction/models

# %%
# !pip install numpy==1.16.0

# %%
# !python test.py
# Out:
# gpu_ids:[0, 1, 2, 3]
# onegpu:2
# num_epochs:150
# add_epoch:0
# iter_per_epoch:2000
# init_lr:0.0002
# alpha:0.999
# train_path:./data/citypersons
# train_random:True
# network:resnet50
# point:center
# scale:h
# num_scale:1
# offset:True
# down:4
# radius:2
# use_horizontal_flips:True
# brightness:(0.5, 2, 0.5)
# size_train:(336, 448)
# size_test:(1280, 2560)
# img_channel_mean:[103.939, 116.779, 123.68]
# caffemodel:False
# teacher:True
# test_path:./data/citypersons
# val:True
# val_frequency:1
# 1/500
# 2/500
# 3/500
# 4/500
# 5/500
# 6/500
# 7/500
# 8/500
# 9/500
# 10/500
# 11/500
# 12/500
# 13/500
# 14/500
# 15/500
# 16/500
# 17/500
# 18/500
# 19/500
# 20/500
# 21/500
# 22/500
# 23/500
# 24/500
# 25/500
# 26/500
# 27/500
# 28/500
# 29/500
# 30/500
# 31/500
# 32/500
# 33/500
# 34/500
# 35/500
# 36/500
# 37/500
# 38/500
# 39/500
# 40/500
# 41/500
# 42/500
# 43/500
# 44/500
# 45/500
# 46/500
# 47/500
# 48/500
# 49/500
# 50/500
# 51/500
# 52/500
# 53/500
# 54/500
# 55/500
# ...
